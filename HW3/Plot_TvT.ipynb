# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#reading logfile from course GIT
df = pd.read_csv('./Na-aimd/cluster24.log','\s+',header=0)
#print(df['T[K]'])

# Plotting Temperature V Time 
fig = plt.figure(figsize=(10,10))

#plt.plot(df['Time[ps]'],df['T[K]'])

#Plotting thi first failed run
#df = pd.read_csv('./MDoutfirst.log','\s+',header=0)
# Plotting Temperature V Time 
#plt.plot(df['Time[ps]'],df['T[K]'])

#reading logfile from course GIT
df = pd.read_csv('./MDout.log','\s+',header=0)

# Plotting Temperature V Time 
fig = plt.figure(figsize = (9,5))
ax = fig.add_subplot()
ax.plot(df['Time[ps]'],df['T[K]'])
ax.set_xlabel('time [ps]')
ax.set_ylabel('Temperature [K]')
# THe system is probably equilibrated at around  1,5 ps
# Out:
# Text(0, 0.5, 'Temperature [K]')
